# %% [markdown]
# # Week 1 Exercises
#
# ***Karlie Schwartzwald
# DSC 550 Fall 2022
# Bellevue University***

# %% [markdown]
# **Change Control Log:**
#
# Change#: 1
# Change(s) Made: Answered first question.
# Date of Change:  8/31/2022
# Author: Karlie Schwartzwald
# Change Approved by: Karlie Schwartzwald
# Date Moved to Production: 9/4/2022
#
# Change#: 2
# Change(s) Made: Worked on SNES questions and finished all except the last question.
# Date of Change:  9/1/2022
# Author: Karlie Schwartzwald
# Change Approved by: Karlie Schwartzwald
# Date Moved to Production: 9/4/2022
#
# Change#: 3
# Change(s) Made: Finished last question.
# Date of Change:  9/2/2022
# Author: Karlie Schwartzwald
# Change Approved by: Karlie Schwartzwald
# Date Moved to Production: 9/4/2022

# %%
# Libraries
import numpy as np
import pandas as pd
import statistics

# %% [markdown]
# #### Load the dataset as a Pandas data frame.

# %%
#read the data into dataframe
game_sales = pd.read_csv('archive/Video_Games_Sales_as_at_22_Dec_2016.csv')

# %% [markdown]
# #### Display the first ten rows of data.

# %%
# first ten rows
game_sales.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %% [markdown]
# #### Find the dimensions (number of rows and columns) in the data frame. What do these two numbers represent in the context of the data?

# %%
# dimension of the dataframe
size = game_sales.shape
print(f'There are {size[0]} rows and {size[1]} columns. The number of rows represents the number of video games in the database. The coliumns represent how many attributes were recorded for each entry.')
# Out:
# There are 16719 rows and 16 columns. The number of rows represents the number of video games in the database. The coliumns represent how many attributes were recorded for each entry.

# %% [markdown]
# #### Find the top five games by critic score.

# %%
# top 5 games by critic score
game_sales[['Name', 'Platform', 'Critic_Score']].sort_values(by = 'Critic_Score', axis=0, ascending=False).head(5)
# Out:
#                           Name Platform  Critic_Score
# 227   Tony Hawk's Pro Skater 2       PS          98.0
# 57         Grand Theft Auto IV      PS3          98.0
# 51         Grand Theft Auto IV     X360          98.0
# 5350               SoulCalibur       DC          98.0
# 165         Grand Theft Auto V     XOne          97.0

# %% [markdown]
# #### Find the number of video games in the data frame in each genre.

# %%
game_sales[['Name', 'Genre']].groupby('Genre').count()
# Out:
#               Name
# Genre
# Action        3370
# Adventure     1303
# Fighting       849
# Misc          1750
# Platform       888
# Puzzle         580
# Racing        1249
# Role-Playing  1500
# Shooter       1323
# Simulation     874
# Sports        2348
# Strategy       683

# %% [markdown]
# #### Find the first five games in the data frame on the SNES platform.

# %%
# filter rows based on condition
games_sales_SNES = game_sales[game_sales['Platform'] == "SNES"]
games_sales_SNES.head(5)
# Out:
#                                      Name Platform  Year_of_Release     Genre  \
# 18                      Super Mario World     SNES           1990.0  Platform
# 56                  Super Mario All-Stars     SNES           1993.0  Platform
# 71                    Donkey Kong Country     SNES           1994.0  Platform
# 76                       Super Mario Kart     SNES           1992.0    Racing
# 137  Street Fighter II: The World Warrior     SNES           1992.0  Fighting
#
#     Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 18   Nintendo     12.78      3.75      3.54         0.55         20.61
# 56   Nintendo      5.99      2.15      2.12         0.29         10.55
# 71   Nintendo      4.36      1.71      3.00         0.23          9.30
# 76   Nintendo      3.54      1.24      3.81         0.18          8.76
# 137    Capcom      2.47      0.83      2.87         0.12          6.30
#
# ...

# %% [markdown]
# #### Find the five publishers with the highest total global sales.
# Note: You will need to calculate the total global sales for each publisher to do this.

# %%
# group by publisher, sum total sales, sort by sales, display top 5
game_sales[['Name', 'Publisher', 'Global_Sales']].groupby('Publisher').sum().sort_values('Global_Sales', ascending = False).head(5)
# Out:
#                              Global_Sales
# Publisher
# Nintendo                          1788.81
# Electronic Arts                   1116.96
# Activision                         731.16
# Sony Computer Entertainment        606.48
# Ubisoft                            471.61

# %% [markdown]
# #### Create a new column in the data frame that calculates the percentage of global sales from North America. Display the first five rows of the new data frame.

# %%
game_sales['%Sales_from_NA'] = game_sales['NA_Sales']/game_sales['Global_Sales']
game_sales.head(5)
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
# ...

# %% [markdown]
# #### Find the number NaN entries (missing data values) in each column.

# %%
game_sales.isna().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# %Sales_from_NA        0
# dtype: int64

# %% [markdown]
# #### Try to calculate the median user score of all the video games. You will likely run into an error because some of the user score entries are a non-numerical string that cannot be converted to a float. Find and replace this string with NaN and then calculate the median. Then, replace all NaN entries in the user score column with the median value.

# %%
# This produces an error:
game_sales['User_Score'].median()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmedian(values, axis, skipna, mask)
#     718         try:
# --> 719             values = values.astype("f8")
#     720         except ValueError as err:
#
# ValueError: could not convert string to float: 'tbd'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24952/3850839290.py in <module>
#       1 # This produces an error:
# ----> 2 game_sales['User_Score'].median(axis=0)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in median(self, axis, skipna, level, numeric_only, **kwargs)
#   10800             self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs
#   10801         ):
# ...

# %%
# Replace the non-numerical string entries with 'NaN'
game_sales['User_Score'] = game_sales['User_Score'].apply(lambda x: pd.to_numeric(x, errors='coerce') )
game_sales['User_Score']
# Out:
# 0        8.0
# 1        NaN
# 2        8.3
# 3        8.0
# 4        NaN
#         ...
# 16714    NaN
# 16715    NaN
# 16716    NaN
# 16717    NaN
# 16718    NaN
# Name: User_Score, Length: 16719, dtype: float64

# %%
# fill NaN with median value
game_sales['User_Score'].fillna(game_sales['User_Score'].median())
# Out:
# 0        8.0
# 1        7.5
# 2        8.3
# 3        8.0
# 4        7.5
#         ...
# 16714    7.5
# 16715    7.5
# 16716    7.5
# 16717    7.5
# 16718    7.5
# Name: User_Score, Length: 16719, dtype: float64
